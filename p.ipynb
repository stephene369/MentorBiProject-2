# %%
import pandas as pd

# %%
# Ajout de toutes les informations demandées (Nom complet de la société, CFO HQ : nom + photo + source, Filiale : nom, pays, CFO, WhatsApp, source)
data_full = [
    {
        "Nom de la société (HQ)": "Seres Technologies",
        "Pays HQ": "France",
        "Nom CFO (HQ)": "Marella Thorell",
        "Photo CFO (HQ)": "https://www.serestherapeutics.com/wp-content/uploads/2024/04/Marella-Thorell-EVP_CFO-600x600.png",
        "Source CFO (HQ)": "https://www.serestherapeutics.com/about-us/#:~:text=Marella%20Thorell%20is%20Executive%20Vice,Financial%20Officer%20of%20Evelo%20Biosciences.",
        "Nom filiale": "Asia Digital EU",
        "Pays filiale": "Allemagne",
        "Nom CFO (filiale)": "Clara Müller",
        "WhatsApp CFO (filiale)": "+49 1520 1234567",
        "Source CFO (filiale)": "https://zoominfo.com/claramuller",
        "Statut de vérification": "Vérifié WhatsApp (testé 21/05/25)"
    },
   
]

df_full = pd.DataFrame(data_full)
file_path_full = "/mnt/data/exemple_contacts_whatsapp_complet.xlsx"
df_full.to_excel(file_path_full, index=False)

import ace_tools as tools; tools.display_dataframe_to_user(name="Exemple Complet Contacts WhatsApp", dataframe=df_full)

file_path_full
